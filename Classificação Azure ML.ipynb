# %% [markdown]
# # AZURE MACHINE LEARNING

# %% [markdown]
# #### Modelo preditivo no Azure Machine Learning que classifique pacientes de mamografia como maligno ou benigno utilizando o SVM.

# %% [markdown]
# Criado apenas para título de comparação com o R e Python contidos nessa mesma pasta do Github.

# %%
from IPython.display import Image
Image(filename='C:\Projetos Python\Azure/azure1.png')

# %%
Image(filename='C:\Projetos Python\Azure/azure2.png')
